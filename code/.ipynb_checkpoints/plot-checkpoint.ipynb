# %%
import arviz as az
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pymc as pm
import pytensor
import pytensor.tensor as pt
import seaborn as sns 

from numba import njit
from pymc.ode import DifferentialEquation
from pytensor.compile.ops import as_op
from scipy.integrate import odeint
from scipy.optimize import least_squares
from scipy.optimize import leastsq

from sklearn import linear_model
from numpy.linalg import norm

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('para1_seg.csv')
sns.boxplot(x = df['Interval'], 
            y = df['Cosine_b'], 
            hue = df['Optimization'])
# Out:
# <AxesSubplot: xlabel='Interval', ylabel='Cosine_b'>

# %%
sns.barplot(x = df['Interval'], 
            y = df['Cosine_b'], 
            hue = df['Optimization'])
# Out:
# <AxesSubplot: xlabel='Interval', ylabel='Cosine_b'>

# %%
df = pd.read_csv('para1_len.csv')
sns.boxplot(x = df['Range'], 
            y = df['Cosine_b'], 
            hue = df['Optimization'])
# Out:
# <AxesSubplot: xlabel='Range', ylabel='Cosine_b'>

# %%
sns.barplot(x = df['Range'], 
            y = df['Cosine_b'], 
            hue = df['Optimization'])
# Out:
# <AxesSubplot: xlabel='Range', ylabel='Cosine_b'>

# %%
df = pd.read_csv('noise_para1_seg.csv')
sns.boxplot(x = df['Interval'], 
            y = df['Cosine_b'], 
            hue = df['Optimization'])
# Out:
# <AxesSubplot: xlabel='Interval', ylabel='Cosine_b'>

# %%
df = pd.read_csv('noise_para1_seg.csv')
sns.barplot(x = df['Interval'], 
            y = df['Cosine_b'], 
            hue = df['Optimization'])
# Out:
# <AxesSubplot: xlabel='Interval', ylabel='Cosine_b'>

# %%
df = pd.read_csv('noise_para1_len.csv')
sns.boxplot(x = df['Range'], 
            y = df['Cosine_b'], 
            hue = df['Optimization'])
# Out:
# <AxesSubplot: xlabel='Range', ylabel='Cosine_b'>

# %%
df = pd.read_csv('noise_para1_len.csv')
sns.barplot(x = df['Range'], 
            y = df['Cosine_b'], 
            hue = df['Optimization'])
# Out:
# <AxesSubplot: xlabel='Range', ylabel='Cosine_b'>
